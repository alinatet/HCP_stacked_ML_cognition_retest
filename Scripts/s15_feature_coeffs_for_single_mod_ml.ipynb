# %%
import pandas as pd
import numpy as np
import os
import glob
from nilearn import datasets, image
from nilearn import plotting
# Out:
# /home/narunlab/.local/lib/python3.7/site-packages/nilearn/datasets/__init__.py:96: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
path = '/media/DataD800/Alina/MLtables/output_CogTotalComp_Unadj_1/'

# %%
#load table of matchings between Glasser parcels and Cole-Anticevic nets
match_net_tab = pd.read_csv('/home/narunlab/Documents/HCP_files_scripts/HCP_analysis/atlases/Glasser-Cole_match_table.csv')
display(match_net_tab)
# Out:
#      orig_order  left_first_order  Cole_net_order name_Glasser  \
# 0             1               181               1     R_V1_ROI
# 1             2               182               2    R_MST_ROI
# 2             3               183               2     R_V6_ROI
# 3             4               184               2     R_V2_ROI
# 4             5               185               2     R_V3_ROI
# ..          ...               ...             ...          ...
# 355         356               176               9  L_STSva_ROI
# 356         357               177               9   L_TE1m_ROI
# 357         358               178               4     L_PI_ROI
# 358         359               179               4  L_a32pr_ROI
# 359         360               180               4    L_p24_ROI
#
#          Cole_net_name
# 0              Visual1
# 1              Visual2
# 2              Visual2
# 3              Visual2
# 4              Visual2
# ..                 ...
# 355            Default
# 356            Default
# 357  Cingulo-Opercular
# 358  Cingulo-Opercular
# 359  Cingulo-Opercular
#
# [360 rows x 5 columns]

# %%
#load table with voxels coordinate for Glasser atlas in MNI

gla_mni = pd.read_csv('/home/narunlab/Documents/HCP_files_scripts/HCP_analysis/atlases/HCP-MMP1_UniqueRegionList.csv')
gla_mni.iloc[:,-2] = gla_mni.iloc[:,-2].round().astype('Int64', errors='ignore')
gla_mni.iloc[:,-3] = gla_mni.iloc[:,-3].round().astype('Int64', errors='ignore')
gla_mni.iloc[:,-4] = gla_mni.iloc[:,-4].round().astype('Int64', errors='ignore')
display(gla_mni)
# Out:
#     regionName                   regionLongName regionIdLabel LR region  Lobe  \
# 0         V1_L          Primary_Visual_Cortex_L           1_L  L     V1   Occ
# 1        MST_L  Medial_Superior_Temporal_Area_L           2_L  L    MST   Occ
# 2         V6_L              Sixth_Visual_Area_L           3_L  L     V6   Occ
# 3         V2_L             Second_Visual_Area_L           4_L  L     V2   Occ
# 4         V3_L              Third_Visual_Area_L           5_L  L     V3   Occ
# ..         ...                              ...           ... ..    ...   ...
# 355    STSva_R             Area_STSv_anterior_R         376_R  R  STSva  Temp
# 356     TE1m_R                Area_TE1_Middle_R         377_R  R   TE1m  Temp
# 357       PI_R              Para-Insular_Area_R         378_R  R     PI  Temp
# 358    a32pr_R         Area_anterior_32_prime_R         379_R  R  a32pr    Fr
# 359      p24_R              Area_posterior_24_R         380_R  R    p24    Fr
#
#                                        cortex  regionID  Cortex_ID  x-cog  \
# 0                              Primary_Visual         1          1    100
# 1    MT+_Complex_and_Neighboring_Visual_Areas         2          5    132
# 2                        Dorsal_Stream_Visual         3          3    105
# 3                                Early_Visual         4          2    102
# 4                                Early_Visual         5          2    108
# ..                                        ...       ...        ...    ...
# 355                      Auditory_Association       376         11     33
# 356                          Lateral_Temporal       377         14     26
# 357             Insular_and_Frontal_Opercular       378         12     47
# 358  Anterior_Cingulate_and_Medial_Prefrontal       379         19     82
# 359  Anterior_Cingulate_and_Medial_Prefrontal       380         19     86
#
#      y-cog  z-cog  volmm
# 0       41     72   6717
# 1       59     82    336
# 2       44    104   1009
# 3       44     74   6220
# 4       41     77   4994
# ..     ...    ...    ...
# 355    118     54   1720
# 356    102     53   2592
# 357    123     58    898
# 358    154    103    827
# 359    161     89   1403
#
# [360 rows x 13 columns]

# %%
#load fsl template for transformation

niimg = image.load_img('/usr/local/fsl/data/standard/MNI152_T1_1mm_brain.nii.gz')

# %%
# transformation from voxel to MNI coordinates

dmn_coords = [tuple(list(gla_mni.iloc[i,-4:-1])) for i in range(len(gla_mni.index))]
dmn_coords_MNI = [image.coord_transform(dmn_coords[i][0], dmn_coords[i][1],dmn_coords[i][2], niimg.affine) for i in range(len(dmn_coords))]
#print(dmn_coords_MNI)
view = plotting.view_markers(dmn_coords_MNI, marker_size=10)
view.open_in_browser() 
gla_mni.iloc[:,-4] = [dmn_coords_MNI[i][0] for i in  range(len(dmn_coords_MNI))]
gla_mni.iloc[:,-3] = [dmn_coords_MNI[i][1] for i in  range(len(dmn_coords_MNI))]
gla_mni.iloc[:,-2] = [dmn_coords_MNI[i][2] for i in  range(len(dmn_coords_MNI))]
display(gla_mni)
# Out:
#     regionName                   regionLongName regionIdLabel LR region  Lobe  \
# 0         V1_L          Primary_Visual_Cortex_L           1_L  L     V1   Occ
# 1        MST_L  Medial_Superior_Temporal_Area_L           2_L  L    MST   Occ
# 2         V6_L              Sixth_Visual_Area_L           3_L  L     V6   Occ
# 3         V2_L             Second_Visual_Area_L           4_L  L     V2   Occ
# 4         V3_L              Third_Visual_Area_L           5_L  L     V3   Occ
# ..         ...                              ...           ... ..    ...   ...
# 355    STSva_R             Area_STSv_anterior_R         376_R  R  STSva  Temp
# 356     TE1m_R                Area_TE1_Middle_R         377_R  R   TE1m  Temp
# 357       PI_R              Para-Insular_Area_R         378_R  R     PI  Temp
# 358    a32pr_R         Area_anterior_32_prime_R         379_R  R  a32pr    Fr
# 359      p24_R              Area_posterior_24_R         380_R  R    p24    Fr
#
#                                        cortex  regionID  Cortex_ID  x-cog  \
# 0                              Primary_Visual         1          1  -10.0
# 1    MT+_Complex_and_Neighboring_Visual_Areas         2          5  -42.0
# 2                        Dorsal_Stream_Visual         3          3  -15.0
# 3                                Early_Visual         4          2  -12.0
# 4                                Early_Visual         5          2  -18.0
# ..                                        ...       ...        ...    ...
# 355                      Auditory_Association       376         11   57.0
# 356                          Lateral_Temporal       377         14   64.0
# 357             Insular_and_Frontal_Opercular       378         12   43.0
# 358  Anterior_Cingulate_and_Medial_Prefrontal       379         19    8.0
# 359  Anterior_Cingulate_and_Medial_Prefrontal       380         19    4.0
#
#      y-cog  z-cog  volmm
# 0    -85.0    0.0   6717
# 1    -67.0   10.0    336
# 2    -82.0   32.0   1009
# 3    -82.0    2.0   6220
# 4    -85.0    5.0   4994
# ..     ...    ...    ...
# 355   -8.0  -18.0   1720
# 356  -24.0  -19.0   2592
# 357   -3.0  -14.0    898
# 358   28.0   31.0    827
# 359   35.0   17.0   1403
#
# [360 rows x 13 columns]

# %%
#Read modality names

mods = sorted(list(set([n.split('/')[-1].split('_')[0] for n in sorted(list(glob.glob(path+'*_elnet_coeffs.csv')))])))
mods = [mods[0], mods[1], mods[11], mods[10], mods[8], mods[2], mods[3], mods[4], mods[6], mods[7], mods[9], mods[12]]
print(mods)
# Out:
# ['VolBrain', 'cort', 'surf', 'subc', 'rest', 'emo', 'gam', 'lan', 'mot', 'rel', 'soc', 'wm']

# %%
#load modalities tables into dictionaries and calculate mean and std for each parcel

dct={}
dct_std={}
for mod in mods:
    dct[mod] = pd.read_csv(path+mod+'_elnet_coeffs.csv', index_col=0).mean()
    dct_std[mod] = pd.read_csv(path+mod+'_elnet_coeffs.csv', index_col=0).std()

# %%
# replace short parcels name in gla_mni table because of some name mistakes in previos table
mp=[n.split('_')[0]+'_'+n.split('_')[1] for n in np.concatenate([list(dct['emo'].index[:-19])[180:], list(dct['emo'].index[:-19])[:180]], axis=0, dtype=str)]
gla_mni['regionName'] = mp
display(gla_mni)
gla_mni.to_csv('/home/narunlab/Desktop/HCP-MMP1_UniqueRegionList_MNI_transformed.csv')
# Out:
#     regionName                   regionLongName regionIdLabel LR region  Lobe  \
# 0         L_V1          Primary_Visual_Cortex_L           1_L  L     V1   Occ
# 1        L_MST  Medial_Superior_Temporal_Area_L           2_L  L    MST   Occ
# 2         L_V6              Sixth_Visual_Area_L           3_L  L     V6   Occ
# 3         L_V2             Second_Visual_Area_L           4_L  L     V2   Occ
# 4         L_V3              Third_Visual_Area_L           5_L  L     V3   Occ
# ..         ...                              ...           ... ..    ...   ...
# 355    R_STSva             Area_STSv_anterior_R         376_R  R  STSva  Temp
# 356     R_TE1m                Area_TE1_Middle_R         377_R  R   TE1m  Temp
# 357       R_PI              Para-Insular_Area_R         378_R  R     PI  Temp
# 358    R_a32pr         Area_anterior_32_prime_R         379_R  R  a32pr    Fr
# 359      R_p24              Area_posterior_24_R         380_R  R    p24    Fr
#
#                                        cortex  regionID  Cortex_ID  x-cog  \
# 0                              Primary_Visual         1          1  -10.0
# 1    MT+_Complex_and_Neighboring_Visual_Areas         2          5  -42.0
# 2                        Dorsal_Stream_Visual         3          3  -15.0
# 3                                Early_Visual         4          2  -12.0
# 4                                Early_Visual         5          2  -18.0
# ..                                        ...       ...        ...    ...
# 355                      Auditory_Association       376         11   57.0
# 356                          Lateral_Temporal       377         14   64.0
# 357             Insular_and_Frontal_Opercular       378         12   43.0
# 358  Anterior_Cingulate_and_Medial_Prefrontal       379         19    8.0
# 359  Anterior_Cingulate_and_Medial_Prefrontal       380         19    4.0
#
#      y-cog  z-cog  volmm
# 0    -85.0    0.0   6717
# 1    -67.0   10.0    336
# 2    -82.0   32.0   1009
# 3    -82.0    2.0   6220
# 4    -85.0    5.0   4994
# ..     ...    ...    ...
# 355   -8.0  -18.0   1720
# 356  -24.0  -19.0   2592
# 357   -3.0  -14.0    898
# 358   28.0   31.0    827
# 359   35.0   17.0   1403
#
# [360 rows x 13 columns]

# %%
#Assemble tabled for all structural modalities

for mod in mods[:4]:
    print(mod)
    tt1 = dct[mod].abs().sort_values(ascending=False)
    tt2 = dct[mod].reindex(index = tt1.index)
    tt3 = dct_std[mod].reindex(index = tt1.index)
    tt4 =  pd.DataFrame({'Mean Coeff': tt2,
                      'σ Coeff':tt3})
    
    tab1 = dct[mod].abs().sort_values(ascending=False)[:20]
    tab2 = dct[mod].reindex(index = tab1.index)
    tab3 = dct_std[mod].reindex(index = tab1.index)
    dft = pd.DataFrame({'Mean Coeff': tab2,
                      'σ Coeff':tab3})
    display(dft)
    dft.to_csv('/home/narunlab/Desktop/'+str(mod)+'_top20_feature_coef.csv')
    tt4.to_csv('/home/narunlab/Desktop/'+str(mod)+'_all_feature_coef.csv')
    print(' ')
# Out:
# VolBrain
#                            Mean Coeff   σ Coeff
# FS_IntraCranial_Vol          2.148956  3.023507
# FS_TotCort_GM_Vol            1.466275  1.066999
# FS_Tot_WM_Vol               -0.539813  1.421590
# FS_BrainSegVol_eTIV_Ratio    0.385760  1.557693
# FS_SubCort_GM_Vol           -0.373989  0.693668
#
# cort
#                              Mean Coeff   σ Coeff
# lh_G_parietal_sup             -0.541948  0.314258
# lh_G_front_middle             -0.395413  0.242732
# lh_G_temp_sup-G_T_transv       0.362076  0.201698
# rh_G_front_inf-Opercular      -0.258993  0.196281
# rh_S_central                   0.250534  0.261915
# rh_S_parieto_occipital         0.213893  0.227816
# lh_Pole_occipital              0.209709  0.152871
# rh_G_and_S_transv_frontopol   -0.203594  0.212498
# lh_S_circular_insula_ant       0.194684  0.230100
# rh_Lat_Fis-ant-Vertical       -0.190928  0.175358
# lh_G_oc-temp_med-Lingual       0.187541  0.180664
# rh_G_cuneus                    0.180364  0.151881
# lh_S_central                   0.179521  0.186394
# rh_G_and_S_cingul-Mid-Post     0.177950  0.210190
# rh_G_temp_sup-Lateral         -0.171388  0.124552
# lh_S_cingul-Marginalis        -0.166746  0.133376
# rh_S_temporal_transverse       0.163058  0.119284
# rh_G_and_S_cingul-Ant         -0.163047  0.153464
# rh_G_subcallosal              -0.154956  0.191956
# rh_G_pariet_inf-Supramar      -0.153881  0.159622
#
# surf
#                               Mean Coeff   σ Coeff
# lh_G_rectus                    -0.692298  0.389956
# rh_Pole_temporal                0.454175  0.129403
# lh_G_temp_sup-Plan_polar        0.440908  0.432144
# rh_G_precentral                 0.376405  0.286822
# rh_G_and_S_occipital_inf        0.320490  0.246364
# lh_G_temporal_inf               0.311130  0.176249
# lh_G_and_S_cingul-Mid-Post      0.279412  0.278969
# lh_G_occipital_sup              0.267037  0.079933
# rh_G_temp_sup-Plan_polar        0.260910  0.242099
# lh_Pole_temporal                0.252657  0.161842
# rh_G_cuneus                     0.241144  0.399297
# lh_S_oc-temp_med_and_Lingual   -0.238082  0.208839
# rh_G_cingul-Post-dorsal         0.225067  0.243519
# rh_G_orbital                    0.223555  0.169850
# lh_S_cingul-Marginalis          0.214685  0.271604
# lh_S_circular_insula_sup       -0.209582  0.177628
# lh_G_temp_sup-G_T_transv       -0.206013  0.186690
# lh_S_front_middle               0.200520  0.155405
# rh_G_and_S_cingul-Ant          -0.200361  0.211014
# lh_S_central                    0.191330  0.166326
#
# subc
#                          Mean Coeff   σ Coeff
# Left-Cerebellum-Cortex     0.906514  0.657504
# Left-Hippocampus           0.747722  0.508056
# Right-Cerebellum-Cortex    0.463789  0.511151
# Right-Hippocampus          0.325324  0.406737
# Left-Thalamus-Proper       0.198564  0.298937
# Left-Pallidum             -0.197626  0.234184
# Right-Accumbens-area      -0.132185  0.296917
# Left-Caudate               0.048365  0.136796
# Right-Amygdala             0.046453  0.131389
# Right-VentralDC            0.037230  0.072176
# Right-Caudate              0.033568  0.094943
# Left-VentralDC             0.030444  0.064393
# Left-Accumbens-area       -0.029095  0.082292
# Right-Pallidum            -0.028003  0.079205
# Left-Amygdala              0.026949  0.058609
# Left-Putamen              -0.023897  0.067592
# Right-Thalamus-Proper     -0.018878  0.053395
# Brain-Stem                -0.008818  0.024940
# Right-Putamen              0.004172  0.011799

# %%
#for resting state
mod=mods[4]
print(mod)
#read tables and sort by absolute value
tab1 = dct[mod].abs().sort_values(ascending=False)[:20]  #top20 features
tab2 = dct[mod].reindex(index = tab1.index)
tab3 = dct_std[mod].reindex(index = tab1.index)

#read index and split pairs to 2 indexes with purpose to find a Net name for each
ind= tab2.index
ind1 = [j[0] for j in [i.split('-') for i in  tab2.index]]
ind2 = [j[1] for j in [i.split('-') for i in  tab2.index]]

#find match with match table
cole1 = match_net_tab[match_net_tab['name_Glasser'].isin(ind1)] #Cole_net_name
cole2 = match_net_tab[match_net_tab['name_Glasser'].isin(ind2)]

#assign column name_glasser as index
cole1.index= cole1['name_Glasser']
cole2.index= cole2['name_Glasser']

#leave only the name of nets
cole1 = cole1['Cole_net_name']
cole2 = cole2['Cole_net_name']

#reindex according table with top20 features
cole1= cole1.reindex(index=ind1)
cole2= cole2.reindex(index=ind2)

tabnet = pd.DataFrame({'Network 1':list(cole1),
                       'Network 2':list(cole2),
                       'Mean Coeff':tab2
                     }, index=tab2.index).fillna('subcortex')
tabnet.index.name = 'FC ROI Glasser'
tabnet['σ Coeff'] = tab3
tabnet= tabnet.round(2)
tabnet.index = [i.replace('_ROI','') for i in tabnet.index]
tabnet = tabnet.sort_values(by=(['Network 1', 'Network 2']))

display(tabnet)
tabnet.to_csv('/home/narunlab/Desktop/restFCnet_top20_feature_coef.csv')
# Out:
# rest
#                                               Network 1             Network 2  \
# R_PBelt-L_10pp                                 Auditory               Default
# R_TE2a-L_PI                                     Default     Cingulo-Opercular
# L_31pv-L_PGi                                    Default               Default
# L_23d-L_11l                                     Default        Frontoparietal
# R_TE2a-R_TE1m                                   Default        Frontoparietal
# R_STSvp-R_TPOJ3                                 Default  Posterior_Multimodal
# L_10pp-DIENCEPHALON_VENTRAL_RIGHT               Default             subcortex
# R_6a-L_pOFC                            Dorsal_Attention      Orbito-Affective
# R_13l-L_5mv                              Frontoparietal     Cingulo-Opercular
# L_11l-L_31a                              Frontoparietal               Default
# R_a10p-L_10pp                            Frontoparietal               Default
# R_13l-R_s32                              Frontoparietal               Default
# L_a10p-L_13l                             Frontoparietal        Frontoparietal
# L_a10p-L_Pir                             Frontoparietal      Orbito-Affective
# L_AVI-PUTAMEN_LEFT                       Frontoparietal             subcortex
# R_TPOJ1-L_10pp                                 Language               Default
# L_44-L_13l                                     Language        Frontoparietal
# L_PCV-PALLIDUM_LEFT                Posterior_Multimodal             subcortex
# R_7PC-L_43                                  Somatomotor     Cingulo-Opercular
# L_3a-L_s32                                  Somatomotor               Default
#
#                                    Mean Coeff  σ Coeff
# R_PBelt-L_10pp                           0.15     0.19
# R_TE2a-L_PI                              0.15     0.13
# L_31pv-L_PGi                             0.12     0.10
# L_23d-L_11l                             -0.12     0.16
# R_TE2a-R_TE1m                           -0.12     0.26
# R_STSvp-R_TPOJ3                          0.12     0.12
# L_10pp-DIENCEPHALON_VENTRAL_RIGHT        0.17     0.14
# R_6a-L_pOFC                              0.20     0.16
# R_13l-L_5mv                             -0.13     0.16
# L_11l-L_31a                             -0.17     0.22
# R_a10p-L_10pp                            0.15     0.17
# R_13l-R_s32                              0.12     0.16
# L_a10p-L_13l                             0.13     0.14
# L_a10p-L_Pir                            -0.12     0.12
# L_AVI-PUTAMEN_LEFT                      -0.18     0.17
# R_TPOJ1-L_10pp                           0.14     0.13
# L_44-L_13l                               0.19     0.16
# L_PCV-PALLIDUM_LEFT                     -0.14     0.13
# R_7PC-L_43                               0.15     0.16
# L_3a-L_s32                              -0.16     0.15

# %%
#for resting state, all rois table
mod=mods[4]
print(mod)
#read tables and sort by absolute value
tab1 = dct[mod].abs().sort_values(ascending=False)#[:20]  #top20 features
tab2 = dct[mod].reindex(index = tab1.index)
tab3 = dct_std[mod].reindex(index = tab1.index)

#read index and split pairs to 2 indexes with purpose to find a Net name for each
#ind= tab2.index
#ind1 = [j[0] for j in [i.split('-') for i in  tab2.index]]
#ind2 = [j[1] for j in [i.split('-') for i in  tab2.index]]

#find match with match table
#cole1 = match_net_tab[match_net_tab['name_Glasser'].isin(ind1)] #Cole_net_name
#cole2 = match_net_tab[match_net_tab['name_Glasser'].isin(ind2)]

#assign column name_glasser as index
#cole1.index= cole1['name_Glasser']
#cole2.index= cole2['name_Glasser']

#leave only the name of nets
#cole1 = cole1['Cole_net_name']
#cole2 = cole2['Cole_net_name']

#reindex according table with top20 features
#cole1= cole1.reindex(index=ind1)
#cole2= cole2.reindex(index=ind2)

#tabnet = pd.DataFrame({'Network 1':list(cole1),
#                       'Network 2':list(cole2),
#                       'Mean Coeff':tab2
#                     }, index=tab2.index).fillna('subcortex')
tabnet = pd.DataFrame({'Mean Coeff':tab2
                     }, index=tab2.index).fillna('subcortex')

tabnet.index.name = 'FC ROI Glasser'
tabnet['σ Coeff'] = tab3
tabnet= tabnet.round(2)
tabnet.index = [i.replace('_ROI','') for i in tabnet.index]
#tabnet = tabnet.sort_values(by=(['Network 1', 'Network 2']))

display(tabnet)
tabnet.to_csv('/home/narunlab/Desktop/restFCnet_all_feature_coef.csv')
# Out:
# rest
#                                    Mean Coeff  σ Coeff
# R_6a-L_pOFC                              0.20     0.16
# L_44-L_13l                               0.19     0.16
# L_AVI-PUTAMEN_LEFT                      -0.18     0.17
# L_10pp-DIENCEPHALON_VENTRAL_RIGHT        0.17     0.14
# L_11l-L_31a                             -0.17     0.22
# ...                                       ...      ...
# L_7m-L_24dv                              0.00     0.00
# R_44-R_TPOJ3                             0.00     0.00
# R_IFJa-L_24dv                            0.00     0.00
# R_FOP3-R_TGd                            -0.00     0.01
# L_SFL-L_7Pm                             -0.00     0.00
#
# [2908 rows x 2 columns]

# %%
#create tables for task modalities
for mod in mods[5:]:
    if mod != 'gam':
        print(mod)
        tab1 = dct[mod].abs().sort_values(ascending=False)[:20]
        tab2 = dct[mod].reindex(index = tab1.index)
        tab3 = dct_std[mod].reindex(index = tab1.index)
        
        tabnet = match_net_tab[match_net_tab['name_Glasser'].isin(list(tab1.index))].iloc[:,3:]
        tabnet = tabnet.set_index(tabnet['name_Glasser'])
        tabnet = tabnet.reindex(index=tab1.index)
        tabnet['coeff'] = np.array(tab2)
        tabnet['σ Coeff'] = np.array(tab3)
        tabnet = tabnet.reset_index()
        tabnet = tabnet.drop('name_Glasser', axis=1)
        tabnet = tabnet.rename(columns={'index': 'name_Glasser'})
        tabnet['Cole_net_name'] = tabnet['Cole_net_name'].fillna('subcortex')
        tabnet['freq'] = [tabnet['Cole_net_name'].value_counts()[val] for val in tabnet['Cole_net_name']]
        tabnet = tabnet.sort_values(by=['freq', 'Cole_net_name', 'coeff'], ascending=False)
        tabnet = tabnet.drop('freq', axis=1)
        tabnet = tabnet.reset_index(drop=True)
        
        init_lbl_gla = [(str(j[0])+str('_')+str(j[1])) for j in [i.split('_') for i in tabnet['name_Glasser']]]
        #print(init_lbl_gla)
        tabnet['name_Glasser'] = [(str(j[0])+str('_')+str(j[1])) for j in [i.split('_') for i in tabnet['name_Glasser']]]
        tabnet = tabnet.set_index(tabnet['name_Glasser'])
        gla = gla_mni[gla_mni['regionName'].isin(tabnet['name_Glasser'])].loc[:,('regionName', 'regionLongName', 'Lobe', 'cortex', 'x-cog', 'y-cog', 'z-cog')]
        gla = gla.set_index(gla['regionName'])
        gla = gla.reindex(index = tabnet.index)

        tabnet = pd.concat([tabnet, gla], axis=1)

        col_nm = list(tabnet.columns)
        col_nm = [col_nm[i] for i in [0,7, 1, 8,9,10, 2, 3]]

        tabnet =tabnet.loc[:,col_nm]
        tabnet = tabnet.reset_index(drop=True)        
        #tabnet = tabnet.fillna(0)
        tabnet['name_Glasser']=init_lbl_gla
        nnms = ['Glasser ROI', 'Brain Region', 'Network', 'x-MNI', 'y-MNI', 'z-MNI', 'Mean Coeff', 'σ Coeff']
        tabnet.columns = nnms
        tabnet = tabnet.round(2)
        tabnet['x-MNI'] = tabnet['x-MNI'].round().astype('Int64')
        tabnet['y-MNI'] = tabnet['y-MNI'].round().astype('Int64')
        tabnet['z-MNI'] = tabnet['z-MNI'].round().astype('Int64')
        tabnet.index = tabnet['Glasser ROI']
        tabnet.pop('Glasser ROI')
       
        
        display(tabnet)
        tabnet.to_csv('/home/narunlab/Desktop/'+str(mod)+'_top20_feature_coef.csv')
        #tabnet.to_csv('/home/narunlab/Desktop/'+str(mod)+'_all_feature_coef.csv')
        print(' ')
# Out:
# emo
#                                          Brain Region               Network  \
# Glasser ROI
# R_d23ab                           Posterior_Cingulate               Default
# L_PreS                                Medial_Temporal               Default
# L_9p                          Dorsolateral_Prefrontal               Default
# R_PGi                               Inferior_Parietal               Default
# R_8BL                         Dorsolateral_Prefrontal               Default
# L_PHA2                                Medial_Temporal               Default
# L_V2                                     Early_Visual               Visual2
# R_V6                             Dorsal_Stream_Visual               Visual2
# R_V2                                     Early_Visual               Visual2
# R_p24        Anterior_Cingulate_and_Medial_Prefrontal     Cingulo-Opercular
# L_23c           Paracentral_Lobular_and_Mid_Cingulate     Cingulo-Opercular
# R_p24pr      Anterior_Cingulate_and_Medial_Prefrontal     Cingulo-Opercular
# R_V1                                   Primary_Visual               Visual1
# L_V1                                   Primary_Visual               Visual1
# R_POS2                            Posterior_Cingulate        Frontoparietal
# L_POS2                            Posterior_Cingulate        Frontoparietal
# R_STV              Temporo-Parieto-Occipital_Junction  Posterior_Multimodal
# R_Pir                   Insular_and_Frontal_Opercular      Orbito-Affective
# R_TPOJ1            Temporo-Parieto-Occipital_Junction              Language
# L_PEF                                        Premotor      Dorsal_Attention
#
#              x-MNI  y-MNI  z-MNI  Mean Coeff  σ Coeff
# Glasser ROI
# R_d23ab          3    -41     33        0.27     0.22
# L_PreS         -20    -31    -11        0.25     0.13
# L_9p           -19     47     38        0.23     0.22
# R_PGi           52    -60     30        0.20     0.07
# R_8BL           11     43     48        0.17     0.12
# L_PHA2         -31    -36    -14       -0.19     0.22
# L_V2           -12    -82      2        0.23     0.06
# R_V6            18    -77     31        0.19     0.11
# R_V2            13    -78      4        0.18     0.10
# R_p24            4     35     17       -0.18     0.08
# L_23c          -13    -30     42       -0.19     0.12
# R_p24pr          4     -4     41       -0.21     0.08
# R_V1            12    -81      2        0.32     0.15
# L_V1           -10    -85      0        0.31     0.18
# R_POS2           9    -70     37        0.23     0.07
# L_POS2          -9    -73     37        0.22     0.12
# R_STV           59    -44     20        0.20     0.12
# R_Pir           32      7    -19        0.19     0.13
# R_TPOJ1         54    -44     11        0.30     0.17
# L_PEF          -47      0     41       -0.18     0.12
#
# lan
#                                             Brain Region            Network  \
# Glasser ROI
# L_8BM           Anterior_Cingulate_and_Medial_Prefrontal     Frontoparietal
# L_AVI                      Insular_and_Frontal_Opercular     Frontoparietal
# L_13l                          Orbital_and_Polar_Frontal     Frontoparietal
# R_p10p                         Orbital_and_Polar_Frontal     Frontoparietal
# L_IFSa                                  Inferior_Frontal     Frontoparietal
# L_7Pm                                  Superior_Parietal     Frontoparietal
# L_IP1                                  Inferior_Parietal     Frontoparietal
# L_POS2                               Posterior_Cingulate     Frontoparietal
# L_9m            Anterior_Cingulate_and_Medial_Prefrontal            Default
# R_TGd                                   Lateral_Temporal            Default
# L_TGd                                   Lateral_Temporal            Default
# L_47l                                   Inferior_Frontal            Default
# L_PGi                                  Inferior_Parietal            Default
# L_7m                                 Posterior_Cingulate            Default
# L_9p                             Dorsolateral_Prefrontal            Default
# R_6v                                            Premotor        Somatomotor
# R_1                              Somatosensory_and_Motor        Somatomotor
# AMYGDALA_RIGHT                                       NaN          subcortex
# L_PHA3                                   Medial_Temporal   Dorsal_Attention
# R_PSL                 Temporo-Parieto-Occipital_Junction  Cingulo-Opercular
#
#                 x-MNI  y-MNI  z-MNI  Mean Coeff  σ Coeff
# Glasser ROI
# L_8BM              -6     33     44        0.63     0.43
# L_AVI             -31     25     -4        0.40     0.23
# L_13l             -23     28    -21        0.26     0.19
# R_p10p             23     61      1       -0.26     0.22
# L_IFSa            -47     33      9       -0.27     0.22
# L_7Pm              -5    -68     49       -0.28     0.07
# L_IP1             -32    -71     39       -0.28     0.10
# L_POS2             -9    -73     37       -0.38     0.12
# L_9m               -7     54     22        0.65     0.48
# R_TGd              35     14    -37        0.48     0.22
# L_TGd             -37     12    -37        0.36     0.20
# L_47l             -47     29    -12        0.31     0.22
# L_PGi             -49    -65     27        0.30     0.21
# L_7m               -6    -62     34        0.29     0.17
# L_9p              -19     47     38        0.27     0.15
# R_6v               58      7     31        0.55     0.26
# R_1                48    -22     54       -0.28     0.23
# AMYGDALA_RIGHT   <NA>   <NA>   <NA>        0.28     0.08
# L_PHA3            -34    -35    -21       -0.50     0.30
# R_PSL              64    -37     27       -0.52     0.22
#
# mot
#                                          Brain Region               Network  \
# Glasser ROI
# R_PEF                                        Premotor     Cingulo-Opercular
# R_FEF                                        Premotor     Cingulo-Opercular
# L_FEF                                        Premotor     Cingulo-Opercular
# L_SCEF          Paracentral_Lobular_and_Mid_Cingulate     Cingulo-Opercular
# L_46                          Dorsolateral_Prefrontal     Cingulo-Opercular
# R_PFcm                                 Early_Auditory     Cingulo-Opercular
# R_p24        Anterior_Cingulate_and_Medial_Prefrontal     Cingulo-Opercular
# L_SFL                         Dorsolateral_Prefrontal              Language
# L_55b                                        Premotor              Language
# L_IFSp                               Inferior_Frontal              Language
# L_TPOJ1            Temporo-Parieto-Occipital_Junction              Language
# R_V4t        MT+_Complex_and_Neighboring_Visual_Areas               Visual2
# L_FFC                           Ventral_Stream_Visual               Visual2
# L_VMV1                          Ventral_Stream_Visual               Visual2
# R_STSda                          Auditory_Association               Default
# R_31pv                            Posterior_Cingulate               Default
# R_31pd                            Posterior_Cingulate               Default
# R_IFSp                               Inferior_Frontal        Frontoparietal
# R_8BM        Anterior_Cingulate_and_Medial_Prefrontal        Frontoparietal
# L_PCV                             Posterior_Cingulate  Posterior_Multimodal
#
#              x-MNI  y-MNI  z-MNI  Mean Coeff  σ Coeff
# Glasser ROI
# R_PEF           45      2     38        0.26     0.14
# R_FEF           44     -3     51        0.20     0.15
# L_FEF          -43     -7     50        0.18     0.14
# L_SCEF          -7      6     56        0.18     0.10
# L_46           -37     38     33       -0.19     0.08
# R_PFcm          48    -28     22       -0.26     0.17
# R_p24            4     35     17       -0.28     0.18
# L_SFL           -8     17     63        0.22     0.13
# L_55b          -49     -1     50        0.19     0.13
# L_IFSp         -48     24     20        0.18     0.15
# L_TPOJ1        -54    -46      9       -0.18     0.11
# R_V4t           49    -72     -2        0.21     0.10
# L_FFC          -44    -56    -19       -0.19     0.06
# L_VMV1         -20    -52     -8       -0.26     0.08
# R_STSda         51     -1    -17       -0.18     0.11
# R_31pv           9    -43     33       -0.20     0.13
# R_31pd          13    -51     35       -0.24     0.12
# R_IFSp          45     30     17        0.26     0.12
# R_8BM            4     31     46        0.23     0.10
# L_PCV           -6    -50     48       -0.19     0.10
#
# rel
#                                                   Brain Region  \
# Glasser ROI
# R_7m                                       Posterior_Cingulate
# L_23d                                      Posterior_Cingulate
# L_PHA2                                         Medial_Temporal
# R_POS1                                     Posterior_Cingulate
# L_47m                                Orbital_and_Polar_Frontal
# L_FST                 MT+_Complex_and_Neighboring_Visual_Areas
# R_PH                  MT+_Complex_and_Neighboring_Visual_Areas
# L_PIT                                    Ventral_Stream_Visual
# L_PSL                       Temporo-Parieto_Occipital_Junction
# R_45                                          Inferior_Frontal
# L_45                                          Inferior_Frontal
# DIENCEPHALON_VENTRAL                                       NaN
# AMYGDALA_LEFT                                              NaN
# R_IP2                                        Inferior_Parietal
# R_p9-46v                               Dorsolateral_Prefrontal
# R_6a                                                  Premotor
# L_AIP                                        Superior_Parietal
# L_ProS                                     Posterior_Cingulate
# L_FOP2                           Insular_and_Frontal_Opercular
# R_AAIC                           Insular_and_Frontal_Opercular
#
#                                Network  x-MNI  y-MNI  z-MNI  Mean Coeff  \
# Glasser ROI
# R_7m                           Default      5    -60     33        0.22
# L_23d                          Default     -4    -20     38       -0.19
# L_PHA2                         Default    -31    -36    -14       -0.21
# R_POS1                         Default     11    -57     15       -0.26
# L_47m                          Default    -37     31    -17       -0.35
# L_FST                          Visual2    -48    -68      5        0.36
# R_PH                           Visual2     49    -61    -11        0.18
# L_PIT                          Visual2    -47    -77    -11       -0.26
# L_PSL                         Language    -60    -48     25        0.18
# R_45                          Language     50     27      0       -0.22
# L_45                          Language    -52     27      2       -0.22
# DIENCEPHALON_VENTRAL         subcortex   <NA>   <NA>   <NA>        0.18
# AMYGDALA_LEFT                subcortex   <NA>   <NA>   <NA>        0.18
# R_IP2                   Frontoparietal     40    -47     45        0.23
# R_p9-46v                Frontoparietal     46     33     25        0.19
# R_6a                  Dorsal_Attention     26     -2     53        0.21
# L_AIP                 Dorsal_Attention    -40    -39     41        0.21
# L_ProS                         Visual1    -23    -55      3        0.30
# L_FOP2                     Somatomotor    -44     -5     14       -0.22
# R_AAIC                Orbito-Affective     35     15    -12        0.22
#
#                       σ Coeff
# Glasser ROI
# R_7m                     0.18
# L_23d                    0.25
# L_PHA2                   0.14
# R_POS1                   0.21
# L_47m                    0.31
# L_FST                    0.21
# R_PH                     0.10
# L_PIT                    0.19
# L_PSL                    0.10
# R_45                     0.19
# L_45                     0.12
# DIENCEPHALON_VENTRAL     0.12
# AMYGDALA_LEFT            0.22
# R_IP2                    0.14
# R_p9-46v                 0.08
# R_6a                     0.29
# L_AIP                    0.13
# L_ProS                   0.30
# L_FOP2                   0.12
# R_AAIC                   0.07
#
# soc
#                                          Brain Region             Network  \
# Glasser ROI
# R_STSda                          Auditory_Association             Default
# R_7m                              Posterior_Cingulate             Default
# R_PGi                               Inferior_Parietal             Default
# R_STSva                          Auditory_Association             Default
# R_47s                       Orbital_and_Polar_Frontal             Default
# L_PGi                               Inferior_Parietal             Default
# R_TPOJ1            Temporo-Parieto-Occipital_Junction            Language
# R_45                                 Inferior_Frontal            Language
# R_TGv                                Lateral_Temporal            Language
# R_STSdp                          Auditory_Association            Language
# R_SFL                         Dorsolateral_Prefrontal            Language
# R_MST        MT+_Complex_and_Neighboring_Visual_Areas             Visual2
# L_V3B                            Dorsal_Stream_Visual             Visual2
# L_5L            Paracentral_Lobular_and_Mid_Cingulate         Somatomotor
# R_5L            Paracentral_Lobular_and_Mid_Cingulate         Somatomotor
# L_MI                    Insular_and_Frontal_Opercular   Cingulo-Opercular
# R_FOP3                  Insular_and_Frontal_Opercular   Cingulo-Opercular
# R_TF                                  Medial_Temporal  Ventral_Multimodal
# L_Pir                   Insular_and_Frontal_Opercular    Orbito-Affective
# L_7Pm                               Superior_Parietal      Frontoparietal
#
#              x-MNI  y-MNI  z-MNI  Mean Coeff  σ Coeff
# Glasser ROI
# R_STSda         51     -1    -17        0.40     0.21
# R_7m             5    -60     33        0.28     0.14
# R_PGi           52    -60     30        0.22     0.15
# R_STSva         57     -8    -18        0.19     0.11
# R_47s           30     20    -21        0.19     0.10
# L_PGi          -49    -65     27        0.15     0.09
# R_TPOJ1         54    -44     11        0.32     0.10
# R_45            50     27      0        0.24     0.08
# R_TGv           33     -2    -46        0.23     0.13
# R_STSdp         48    -28     -2        0.18     0.12
# R_SFL            7     16     65        0.16     0.10
# R_MST           46    -62      6       -0.24     0.14
# L_V3B          -28    -83     16       -0.27     0.12
# L_5L           -15    -49     72       -0.18     0.14
# R_5L            13    -48     74       -0.28     0.31
# L_MI           -38     10      1        0.24     0.19
# R_FOP3          34      8     11        0.15     0.08
# R_TF            40    -20    -31        0.21     0.19
# L_Pir          -33      5    -18        0.15     0.11
# L_7Pm           -5    -68     49        0.26     0.12
#
# wm
#                                          Brain Region               Network  \
# Glasser ROI
# L_7Pm                               Superior_Parietal        Frontoparietal
# R_7Pm                               Superior_Parietal        Frontoparietal
# R_IP2                               Inferior_Parietal        Frontoparietal
# R_AVI                   Insular_and_Frontal_Opercular        Frontoparietal
# R_d32        Anterior_Cingulate_and_Medial_Prefrontal        Frontoparietal
# R_LIPd                              Superior_Parietal      Dorsal_Attention
# L_MIP                               Superior_Parietal      Dorsal_Attention
# R_7PL                               Superior_Parietal      Dorsal_Attention
# L_7PL                               Superior_Parietal      Dorsal_Attention
# R_EC                                  Medial_Temporal               Default
# L_PGs                               Inferior_Parietal               Default
# L_31pv                            Posterior_Cingulate               Default
# R_8BL                         Dorsolateral_Prefrontal               Default
# L_FOP3                  Insular_and_Frontal_Opercular     Cingulo-Opercular
# R_IFSa                               Inferior_Frontal     Cingulo-Opercular
# R_PFop                              Inferior_Parietal     Cingulo-Opercular
# L_PCV                             Posterior_Cingulate  Posterior_Multimodal
# R_PCV                             Posterior_Cingulate  Posterior_Multimodal
# L_PIT                           Ventral_Stream_Visual               Visual2
# L_6mp           Paracentral_Lobular_and_Mid_Cingulate           Somatomotor
#
#              x-MNI  y-MNI  z-MNI  Mean Coeff  σ Coeff
# Glasser ROI
# L_7Pm           -5    -68     49        0.44     0.24
# R_7Pm            5    -67     50        0.44     0.15
# R_IP2           40    -47     45        0.34     0.11
# R_AVI           32     25     -4        0.30     0.19
# R_d32            6     39     27        0.28     0.22
# R_LIPd          30    -55     44        0.31     0.16
# L_MIP          -26    -67     47        0.29     0.10
# R_7PL           12    -73     58        0.29     0.24
# L_7PL          -15    -74     56        0.29     0.14
# R_EC            20    -11    -27        0.33     0.16
# L_PGs          -42    -77     38       -0.28     0.22
# L_31pv         -10    -44     33       -0.28     0.29
# R_8BL           11     43     48       -0.44     0.19
# L_FOP3         -36      3     12       -0.29     0.23
# R_IFSa          48     39      2       -0.31     0.13
# R_PFop          62    -20     23       -0.50     0.16
# L_PCV           -6    -50     48        0.48     0.14
# R_PCV            5    -52     50        0.40     0.19
# L_PIT          -47    -77    -11       -0.29     0.21
# L_6mp          -10    -15     69       -0.30     0.24

# %%
avertask_abs = pd.read_csv(path+'mean_tasksAbs_set2_brain_elnet_coeffs.csv', index_col=0)['0']#.sort_values(ascending=False)[:10]

tab1 = avertask_abs.abs().sort_values(ascending=False)[:20]
tab2 = avertask_abs.reindex(index = tab1.index)
#tab3 = 

tabnet = match_net_tab[match_net_tab['name_Glasser'].isin(list(tab1.index))].iloc[:,3:]
tabnet = tabnet.set_index(tabnet['name_Glasser'])
tabnet = tabnet.reindex(index=tab1.index)
tabnet['coeff'] = np.array(tab2)
tabnet = tabnet.reset_index()
tabnet = tabnet.drop('name_Glasser', axis=1)
tabnet = tabnet.rename(columns={'index': 'name_Glasser'})
tabnet['Cole_net_name'] = tabnet['Cole_net_name'].fillna('subcortex')
tabnet['freq'] = [tabnet['Cole_net_name'].value_counts()[val] for val in tabnet['Cole_net_name']]
tabnet = tabnet.sort_values(by=['freq', 'Cole_net_name', 'coeff'], ascending=False)
tabnet = tabnet.drop('freq', axis=1)
tabnet = tabnet.reset_index(drop=True)

init_lbl_gla = [(str(j[0])+str('_')+str(j[1])) for j in [i.split('_') for i in tabnet['name_Glasser']]]

tabnet['name_Glasser'] = [(str(j[0])+str('_')+str(j[1])) for j in [i.split('_') for i in tabnet['name_Glasser']]]
tabnet = tabnet.set_index(tabnet['name_Glasser'])
gla = gla_mni[gla_mni['regionName'].isin(tabnet['name_Glasser'])].loc[:,('regionName', 'regionLongName', 'Lobe', 'cortex', 'x-cog', 'y-cog', 'z-cog')]
gla = gla.set_index(gla['regionName'])
gla = gla.reindex(index = tabnet.index)

tabnet = pd.concat([tabnet, gla], axis=1)

col_nm = list(tabnet.columns)
col_nm = [col_nm[i] for i in [0,6, 1, 7,8,9, 2]]

tabnet =tabnet.loc[:,col_nm]
tabnet = tabnet.reset_index(drop=True)
tabnet['name_Glasser']=init_lbl_gla
nnms = ['Glasser ROI', 'Cortex', 'Network', 'x-MNI', 'y-MNI', 'z-MNI', 'Magnitude']
tabnet.columns = nnms
tabnet = tabnet.round(2)

tabnet['x-MNI'] = tabnet['x-MNI'].round().astype('Int64')
tabnet['y-MNI'] = tabnet['y-MNI'].round().astype('Int64')
tabnet['z-MNI'] = tabnet['z-MNI'].round().astype('Int64')
tabnet.index = tabnet['Glasser ROI']
tabnet.pop('Glasser ROI')
#tabnet = tabnet.dropna()

display(tabnet)
tabnet.to_csv('/home/narunlab/Desktop/taskAbsMag_top20_feature_coef.csv')
#tabnet.to_csv('/home/narunlab/Desktop/taskAbsMag_all_feature_coef.csv')
# Out:
#                                                Cortex               Network  \
# Glasser ROI
# L_7Pm                               Superior_Parietal        Frontoparietal
# L_8BM        Anterior_Cingulate_and_Medial_Prefrontal        Frontoparietal
# R_IP2                               Inferior_Parietal        Frontoparietal
# R_7Pm                               Superior_Parietal        Frontoparietal
# L_IP1                               Inferior_Parietal        Frontoparietal
# L_p47r                               Inferior_Frontal        Frontoparietal
# R_p10p                      Orbital_and_Polar_Frontal        Frontoparietal
# L_AVI                   Insular_and_Frontal_Opercular        Frontoparietal
# R_8BL                         Dorsolateral_Prefrontal               Default
# L_9m         Anterior_Cingulate_and_Medial_Prefrontal               Default
# R_TGd                                Lateral_Temporal               Default
# R_PCV                             Posterior_Cingulate  Posterior_Multimodal
# L_PCV                             Posterior_Cingulate  Posterior_Multimodal
# L_PHA3                                Medial_Temporal      Dorsal_Attention
# R_LIPd                              Superior_Parietal      Dorsal_Attention
# R_PFop                              Inferior_Parietal     Cingulo-Opercular
# R_PSL              Temporo-Parieto-Occipital_Junction     Cingulo-Opercular
# L_PIT                           Ventral_Stream_Visual               Visual2
# R_6v                                         Premotor           Somatomotor
# R_AAIC                  Insular_and_Frontal_Opercular      Orbito-Affective
#
#              x-MNI  y-MNI  z-MNI  Magnitude
# Glasser ROI
# L_7Pm           -5    -68     49       0.36
# L_8BM           -6     33     44       0.30
# R_IP2           40    -47     45       0.28
# R_7Pm            5    -67     50       0.28
# L_IP1          -32    -71     39       0.24
# L_p47r         -45     43      0       0.24
# R_p10p          23     61      1       0.24
# L_AVI          -31     25     -4       0.24
# R_8BL           11     43     48       0.36
# L_9m            -7     54     22       0.34
# R_TGd           35     14    -37       0.24
# R_PCV            5    -52     50       0.33
# L_PCV           -6    -50     48       0.32
# L_PHA3         -34    -35    -21       0.28
# R_LIPd          30    -55     44       0.24
# R_PFop          62    -20     23       0.30
# R_PSL           64    -37     27       0.29
# L_PIT          -47    -77    -11       0.29
# R_6v            58      7     31       0.35
# R_AAIC          35     15    -12       0.25
